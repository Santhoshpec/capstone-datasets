# %%
storage_account_name = "hexawaretrainingadlstwo"

storage_account_key = "<YOUR_STORAGE_ACCOUNT_KEY>"

raw_container = "raw"

base_path = f"abfss://{raw_container}@{storage_account_name}.dfs.core.windows.net"

bronze_schema = "capstone.santhosh_bronze"
silver_schema = "capstone.santhosh_silver"
gold_schema = "capstone.santhosh_gold"
scd_schema = "capstone.santhosh_scd"

spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net",
    storage_account_key
)
